# %%
from myTransformer import *
from pedalboard_param_utils import *

dac_model_path = dac.utils.download(model_type="44khz")
dac_model = dac.DAC.load(dac_model_path, weights_only=True).to('cuda')
model_dim = 64
key_dim = 32
num_heads = 8
enc_out_dim = 9
ffn_hidden_dim = 32
num_stack=4
num_vocab = len(vocab)

my_model = MyModel(
    dac=dac_model, 
    num_vocab=num_vocab, 
    model_dim=model_dim, 
    key_dim=key_dim, 
    enc_out_dim=enc_out_dim, 
    ffn_hidden_dim=ffn_hidden_dim, 
    num_heads=num_heads,
    num_stack=num_stack
).to("cuda")
# Out:
# /home/yuc3/miniconda3/envs/dac_compatible/lib/python3.8/site-packages/audiotools/ml/layers/base.py:172: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_dict = torch.load(location, "cpu")
# /home/yuc3/miniconda3/envs/dac_compatible/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
from EGFxSetDataParam import *
from ICMTSMTGuitarDataParam import * 
from torch.utils.data import ConcatDataset, DataLoader

egfx_data = EGFxSetData(pedal_dict)
icmt_mono = ICMTSMTGuitarDataMono(pedal_dict)
icmt_poly = ICMTSMTGuitarDataPoly(pedal_dict)

batch_size = 32

combined = ConcatDataset([egfx_data, icmt_mono, icmt_poly])
loader = DataLoader(dataset=combined, batch_size=32, num_workers=4, shuffle=True, collate_fn=collate_data)

# %%
from torch.optim import Adam
from torch.nn import CrossEntropyLoss

lr = 0.0002
optimizer = Adam(my_model.parameters(), lr=lr)
criterion = CrossEntropyLoss(ignore_index=0)

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime 
torch.manual_seed(0)

run_dir = "logs"
# !rm -rf ./logs
run_time = datetime.datetime.now().strftime("%I:%M%p on %B %d, %Y")
logger = SummaryWriter(log_dir=Path(run_dir) / run_time, flush_secs=20)
epochs = 20
device = "cuda"

# %%
for epoch in range(epochs):
    
    # weight batch losses/scores proportional to batch size
    iter_count = 0
    loss_epoch = 0
    
    for batch_idx, batch_data in enumerate(loader):
        audio, pedal_str = batch_data
        my_model.zero_grad()
        
        # train on a batch of inputs
        logits = my_model(audio.to(device), pedal_str[:, :-1].to(device)).transpose(1,2)
        loss_batch = criterion(logits, pedal_str[:, 1:].to(device))
        loss_batch.backward()
        optimizer.step()
        
        # log loss
        loss_epoch += loss_batch.detach().item() * batch_size
        iter_count += batch_size
    
    # plot loss
    loss_epoch /= iter_count
    logger.add_scalar("cross_entropy_loss", loss_epoch, epoch)
    
    if not epoch % 10:
        print(f"Epoch: {epoch + 1}\tCross Entropy Loss: {loss_epoch :0.4f}")
# Out:
# Epoch: 1	Cross Entropy Loss: 242.5048
# Epoch: 11	Cross Entropy Loss: 79.2807

# %%
loader_iter = iter(loader)
source, target = next(loader_iter)
predictions = torch.tensor([vocab.to_num(["<start>"]) for _ in range(32)]).to(device)
max_len = 32
while (predictions.shape[-1] < max_len):  
    logits = my_model(source.to(device), target[:, -1:].to(device))[:, -1:, :]
    print(logits.shape)
    next_word_indices = torch.argmax(logits, dim=-1) # [batch_size, 1, num_vocabs]
    
    predictions = torch.cat((predictions, next_word_indices), dim=1)
# Out:
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])
# torch.Size([32, 1, 83])

# %%
for prediction in predictions.detach(): 
    print(vocab.to_str(prediction.cpu().numpy()))
# Out:
# ['<start>', '<end>', '<sep>', 'reverb_dry_level_1', 'compressor_release_ms_50', 'compressor_ratio_1.5', 'phaser_centre_frequency_hz_600', 'compressor_release_ms_500', 'phaser_centre_frequency_hz_1500', 'phaser_mix_0.5', 'compressor_release_ms_500', 'reverb_damping_0', 'phaser_depth_1', 'chorus_centre_delay_ms_20', 'chorus_depth_0.15', 'reverb_dry_level_1', 'compressor_release_ms_50', 'compressor_release_ms_150', 'phaser_centre_frequency_hz_300', 'chorus_centre_delay_ms_10', 'reverb_room_size_1', 'compressor_release_ms_300', 'compressor_release_ms_50', 'phaser_depth_0.7', 'phaser_depth_0.7', 'chorus_mix_0.5', '<end>', '<sep>', 'chorus_feedback_0.2', 'phaser_centre_frequency_hz_300', 'phaser_depth_0.4', 'phaser_centre_frequency_hz_1500']
# ['<start>', 'phaser_mix_0.5', '<sep>', 'chorus_feedback_0.4', '<sep>', 'phaser_centre_frequency_hz_1500', 'chorus_depth_0.25', '<sep>', 'compressor_ratio_2', 'phaser_feedback_0.6', 'compressor_attack_ms_70', 'chorus_feedback_0.4', 'compressor_attack_ms_10', 'phaser_depth_0.2', 'phaser_mix_0.5', 'compressor_ratio_2', 'chorus_depth_0.25', '<sep>', 'chorus_centre_delay_ms_25', 'phaser_feedback_0.4', 'chorus_mix_0.5', '<sep>', 'chorus_depth_0.25', 'compressor_attack_ms_10', 'reverb_damping_0.5', 'phaser_depth_0.2', 'compressor_release_ms_150', 'compressor_attack_ms_70', 'compressor_attack_ms_100', '<sep>', 'compressor_attack_ms_10', 'chorus_depth_0.15']
# ['<start>', 'chorus_depth_0.25', 'compressor_attack_ms_70', 'compressor_threshold_db_-10', '<sep>', '<sep>', '<sep>', 'phaser_centre_frequency_hz_600', 'phaser_centre_frequency_hz_1500', 'reverb_wet_level_1', 'reverb_width_0.5', 'phaser_feedback_0.6', 'phaser_depth_0.4', 'compressor_ratio_2', 'compressor_ratio_4', '<sep>', 'chorus_mix_1', 'chorus_depth_0.05', 'distortion_drive_db_18', 'phaser_feedback_0.6', '<sep>', '<sep>', '<sep>', '<sep>', 'phaser_feedback_0', 'chorus_mix_0.7', 'chorus_centre_delay_ms_30', '<sep>', 'compressor_attack_ms_10', 'chorus_depth_0.25', '<sep>', 'chorus_feedback_0.2']
# ['<start>', 'phaser_centre_frequency_hz_2000', 'phaser_mix_0.5', 'reverb_room_size_0.7', 'compressor_ratio_10', 'reverb_room_size_0.3', 'compressor_attack_ms_70', 'reverb_dry_level_0.7', 'phaser_feedback_0.6', 'chorus_mix_0.5', 'phaser_feedback_0', 'phaser_depth_0.7', 'phaser_depth_1', '<end>', 'compressor_ratio_10', '<sep>', 'phaser_centre_frequency_hz_2000', '<sep>', 'compressor_attack_ms_70', 'compressor_attack_ms_50', '<sep>', 'phaser_feedback_0.6', '<sep>', '<sep>', '<sep>', '<sep>', '<sep>', '<sep>', 'chorus_mix_1', 'compressor_release_ms_50', 'chorus_mix_0.5', 'phaser_feedback_0.6']
# ['<start>', 'chorus_feedback_0.1', 'reverb_dry_level_1', 'chorus_centre_delay_ms_5', '<sep>', '<sep>', 'phaser_feedback_0.4', 'chorus_mix_0.5', 'chorus_centre_delay_ms_5', 'phaser_mix_0.5', 'compressor_attack_ms_10', 'chorus_centre_delay_ms_5', 'compressor_ratio_2', 'phaser_feedback_0.4', 'phaser_feedback_0.6', 'reverb_wet_level_1', 'compressor_ratio_1.5', 'compressor_ratio_4', 'compressor_attack_ms_100', 'chorus_centre_delay_ms_15', '<sep>', 'compressor_ratio_1.5', 'phaser_mix_0.5', 'phaser_feedback_0.6', 'phaser_mix_0.5', 'phaser_mix_0.5', '<sep>', 'compressor_ratio_4', 'reverb_dry_level_1', '<sep>', 'phaser_feedback_0.4', 'chorus_centre_delay_ms_25']
# ['<start>', 'chorus_mix_1', 'compressor_release_ms_500', 'chorus_centre_delay_ms_10', 'chorus_mix_0.5', 'compressor_ratio_4', '<sep>', 'compressor_ratio_10', 'phaser_feedback_0.6', 'reverb_width_0.7', '<sep>', 'phaser_centre_frequency_hz_800', '<sep>', 'phaser_feedback_0.4', 'reverb_wet_level_0.5', '<sep>', 'reverb_dry_level_1', 'chorus_depth_0.25', '<sep>', 'compressor_ratio_10', 'reverb_dry_level_1', 'chorus_mix_0.7', 'compressor_release_ms_500', 'chorus_mix_1', 'chorus_centre_delay_ms_5', 'reverb_dry_level_0.7', 'reverb_wet_level_1', 'reverb_dry_level_1', 'reverb_width_1', 'chorus_mix_1', 'compressor_release_ms_500', 'reverb_wet_level_0.5']
# ['<start>', 'phaser_centre_frequency_hz_300', 'reverb_wet_level_0.7', 'phaser_centre_frequency_hz_600', 'reverb_dry_level_0.5', 'compressor_ratio_1.5', 'chorus_mix_1', 'reverb_width_0.7', 'reverb_room_size_0.7', 'phaser_mix_0.5', 'reverb_dry_level_1', 'reverb_dry_level_1', 'compressor_release_ms_500', '<sep>', 'compressor_ratio_4', 'phaser_feedback_0.6', 'reverb_damping_0.5', 'phaser_feedback_0.4', 'phaser_feedback_0.4', 'phaser_feedback_0.6', 'compressor_threshold_db_-50', 'compressor_threshold_db_-20', 'phaser_mix_0.5', 'chorus_centre_delay_ms_20', 'reverb_dry_level_0.5', 'phaser_feedback_0.6', 'phaser_feedback_0.4', 'phaser_feedback_0.6', 'phaser_feedback_0.4', 'reverb_dry_level_1', 'chorus_centre_delay_ms_10', '<sep>']
# ['<start>', 'reverb_room_size_0.3', 'reverb_dry_level_1', '<sep>', 'compressor_threshold_db_-40', 'chorus_mix_0.7', 'reverb_dry_level_0.7', 'chorus_feedback_0.1', 'compressor_ratio_1.5', '<sep>', 'reverb_dry_level_0.5', 'compressor_release_ms_500', 'phaser_mix_0.5', 'phaser_mix_0.5', 'compressor_release_ms_500', 'compressor_release_ms_150', 'reverb_damping_0.5', 'compressor_release_ms_100', 'compressor_ratio_1.5', 'compressor_ratio_4', '<sep>', 'distortion_drive_db_24', 'reverb_dry_level_1', 'reverb_dry_level_1', 'compressor_release_ms_500', 'phaser_feedback_0.4', '<sep>', 'compressor_ratio_1.5', 'chorus_mix_0.7', 'phaser_depth_0.7', 'reverb_room_size_0.5', 'compressor_threshold_db_-10']
# ['<start>', 'compressor_attack_ms_100', '<sep>', 'compressor_attack_ms_70', 'compressor_release_ms_100', 'compressor_threshold_db_-20', 'chorus_mix_1', '<sep>', 'chorus_depth_0.15', '<sep>', '<sep>', 'compressor_release_ms_500', 'compressor_release_ms_500', 'chorus_mix_1', 'reverb_width_0.5', 'compressor_ratio_10', 'compressor_attack_ms_10', 'compressor_ratio_4', 'compressor_attack_ms_70', 'phaser_feedback_0.4', 'compressor_threshold_db_-30', 'phaser_centre_frequency_hz_1500', 'phaser_mix_0.5', 'compressor_ratio_4', 'compressor_attack_ms_70', 'chorus_depth_0.25', 'phaser_depth_0.4', 'reverb', 'compressor_ratio_1.5', 'compressor_release_ms_100', '<sep>', 'phaser_rate_hz_3']
# ['<start>', 'phaser_centre_frequency_hz_2000', 'compressor_attack_ms_70', 'chorus_mix_1', '<sep>', '<sep>', 'reverb_wet_level_0.5', 'compressor_ratio_2', 'reverb_dry_level_1', 'compressor_ratio_2', '<sep>', 'compressor_ratio_10', '<sep>', 'reverb_width_0.5', 'chorus_depth_0.05', 'compressor_attack_ms_10', 'compressor_ratio_1.5', 'compressor_attack_ms_100', '<sep>', '<sep>', 'reverb_wet_level_1', 'compressor_ratio_1.5', '<sep>', 'compressor_ratio_4', 'reverb_dry_level_1', 'compressor_release_ms_150', 'reverb_width_0.5', 'compressor_release_ms_150', '<sep>', 'compressor_attack_ms_70', 'compressor_release_ms_500', '<end>']
# ['<start>', 'phaser_centre_frequency_hz_1500', 'phaser_centre_frequency_hz_600', 'compressor_attack_ms_10', 'compressor_ratio_10', 'chorus_feedback_0.4', 'chorus_mix_0.7', 'phaser_depth_0.7', 'chorus_centre_delay_ms_15', 'phaser_rate_hz_1', '<sep>', 'chorus_mix_0.7', '<sep>', '<sep>', 'reverb_dry_level_0.5', 'phaser_mix_0.5', 'compressor_release_ms_300', 'reverb_damping_0', 'phaser_feedback_0', '<sep>', '<sep>', 'reverb_wet_level_0.5', 'compressor_ratio_4', '<sep>', 'phaser_mix_0.5', '<sep>', 'chorus_mix_0.7', 'reverb_width_0.5', 'compressor_attack_ms_70', 'compressor_ratio_1.5', 'chorus_depth_0.15', '<sep>']
# ['<start>', 'compressor_ratio_2', 'compressor_threshold_db_-60', 'compressor_release_ms_100', 'compressor_ratio_2', 'reverb_width_1', 'reverb_width_0.7', 'phaser_depth_0.4', 'phaser_depth_1', '<sep>', 'reverb_dry_level_1', 'compressor_ratio_10', '<sep>', '<sep>', 'compressor_release_ms_500', '<sep>', 'phaser_depth_0.2', 'reverb_damping_0.5', 'compressor_ratio_1.5', 'reverb_width_1', 'phaser_depth_0.4', 'phaser_mix_0.5', 'phaser_mix_0.5', '<sep>', 'compressor_attack_ms_70', 'chorus_depth_0.25', 'compressor_release_ms_150', 'reverb_width_1', 'phaser_depth_0.2', '<sep>', 'compressor_attack_ms_10', 'phaser_depth_0.7']
# ['<start>', 'chorus_feedback_0.4', 'reverb_wet_level_0.7', 'phaser_centre_frequency_hz_800', 'chorus_rate_hz_0.8', '<sep>', '<sep>', 'reverb_width_0.5', 'chorus_depth_0.15', 'compressor_threshold_db_-20', 'compressor_ratio_1.5', 'compressor_release_ms_500', 'compressor_attack_ms_70', 'chorus_mix_0.5', 'chorus_feedback_0.2', 'compressor_ratio_4', 'compressor_release_ms_300', 'compressor_release_ms_150', 'reverb_width_1', 'compressor_release_ms_500', '<sep>', 'reverb_wet_level_1', 'chorus_feedback_0.4', 'chorus_depth_0.05', 'compressor_ratio_4', 'chorus_depth_0.25', 'reverb_width_1', 'compressor_threshold_db_-40', 'reverb_damping_0', 'compressor_release_ms_150', 'compressor_release_ms_300', 'reverb_dry_level_0.7']
# ['<start>', 'phaser_centre_frequency_hz_1500', 'reverb_width_0.5', 'compressor_attack_ms_100', 'chorus_mix_0.7', '<sep>', 'compressor_release_ms_300', '<sep>', 'compressor_attack_ms_10', 'phaser_depth_0.7', 'chorus_feedback_0.1', 'phaser_depth_0.7', '<sep>', '<sep>', 'chorus_centre_delay_ms_15', 'phaser_depth_1', 'compressor_attack_ms_70', 'phaser_depth_1', 'chorus_depth_0.15', '<sep>', 'phaser_depth_0.7', 'phaser_centre_frequency_hz_300', 'compressor_ratio_1.5', 'compressor_ratio_2', 'compressor_attack_ms_100', 'chorus_depth_0.15', '<sep>', 'chorus_feedback_0.2', 'reverb_width_1', 'compressor_attack_ms_70', '<sep>', 'reverb_width_0.7']
# ['<start>', 'phaser_mix_0.5', 'phaser_rate_hz_3', 'chorus_feedback_0.2', 'compressor_release_ms_100', '<sep>', 'chorus_feedback_0.2', 'chorus_centre_delay_ms_10', 'compressor_ratio_4', '<end>', 'reverb_width_0.5', 'chorus_centre_delay_ms_20', 'phaser_depth_0.4', 'compressor_ratio_4', '<sep>', '<sep>', 'compressor_ratio_10', 'reverb_damping_1', 'compressor_ratio_10', '<sep>', 'chorus_centre_delay_ms_10', 'chorus_feedback_0.4', '<sep>', 'chorus_feedback_0.2', 'compressor_attack_ms_70', '<sep>', 'compressor_attack_ms_100', 'chorus_depth_0.05', 'compressor_attack_ms_50', 'phaser_feedback_0.4', 'compressor_ratio_4', 'chorus_feedback_0.1']
# ['<start>', 'compressor_attack_ms_50', 'compressor_attack_ms_100', 'compressor_attack_ms_100', '<end>', 'reverb_room_size_1', 'compressor_ratio_10', 'compressor_ratio_4', 'reverb_damping_0', 'chorus_rate_hz_0.5', '<sep>', '<sep>', 'phaser_depth_1', 'phaser_centre_frequency_hz_1500', 'compressor_attack_ms_100', 'compressor_release_ms_150', '<end>', 'chorus_centre_delay_ms_30', '<sep>', 'chorus_depth_0.15', 'compressor_threshold_db_-30', 'compressor_ratio_4', '<sep>', 'chorus_feedback_0.1', 'compressor_attack_ms_100', '<sep>', '<sep>', 'compressor_threshold_db_-20', 'chorus_depth_0.15', 'phaser_feedback_0.6', 'compressor_ratio_10', 'phaser_centre_frequency_hz_300']
# ['<start>', '<sep>', 'reverb_damping_0', 'compressor_attack_ms_100', 'compressor_release_ms_50', '<sep>', 'compressor_attack_ms_10', 'phaser_centre_frequency_hz_2000', '<sep>', '<sep>', 'compressor_attack_ms_100', 'compressor_attack_ms_10', '<sep>', 'compressor_attack_ms_70', 'phaser_depth_0.2', 'compressor_attack_ms_10', 'chorus_mix_0.5', '<sep>', '<sep>', 'chorus_feedback_0.2', '<sep>', 'chorus_centre_delay_ms_30', '<end>', 'chorus_mix_0.7', '<sep>', 'reverb_room_size_0.1', 'phaser_depth_1', 'phaser_feedback_0.6', 'compressor_attack_ms_100', 'phaser_feedback_0.4', '<end>', '<sep>']
# ['<start>', 'compressor_threshold_db_-30', 'chorus_mix_0.7', '<sep>', 'compressor_ratio_4', '<sep>', 'compressor_attack_ms_100', '<sep>', 'phaser_centre_frequency_hz_800', 'phaser_rate_hz_3', 'reverb_damping_0', 'compressor_ratio_10', 'chorus_rate_hz_0.8', '<sep>', 'chorus_depth_0.05', 'chorus_rate_hz_0.8', '<sep>', 'compressor_ratio_10', 'reverb_room_size_0.7', '<sep>', 'phaser_depth_0.7', '<sep>', 'compressor_attack_ms_70', 'compressor_attack_ms_70', '<sep>', '<sep>', 'phaser_feedback_0.4', 'reverb_room_size_0.7', 'compressor_release_ms_300', 'chorus_depth_0.05', 'chorus_depth_0.05', 'phaser_feedback_0.4']
# ['<start>', 'phaser_feedback_0.4', 'compressor_release_ms_500', 'reverb_room_size_0.7', 'compressor_release_ms_150', 'compressor_ratio_4', 'chorus_centre_delay_ms_20', '<sep>', 'phaser_centre_frequency_hz_600', '<end>', 'compressor_release_ms_150', 'chorus_mix_0.5', 'reverb_width_0.5', 'compressor_release_ms_300', '<end>', 'compressor_release_ms_300', 'compressor_ratio_10', 'chorus_rate_hz_0.8', 'phaser_feedback_0', 'compressor_release_ms_300', '<end>', 'phaser_feedback_0', 'compressor_release_ms_500', '<end>', 'chorus_depth_0.05', '<sep>', '<end>', 'compressor_release_ms_50', 'compressor_attack_ms_10', 'reverb_width_0.5', 'reverb_damping_1', '<sep>']
# ['<start>', 'chorus_mix_1', 'compressor_ratio_4', 'chorus_mix_0.5', 'chorus_depth_0.25', 'reverb_room_size_0.7', 'chorus_mix_0.7', 'compressor_threshold_db_-20', 'phaser_feedback_0.4', '<sep>', 'chorus_mix_1', 'reverb_width_1', 'chorus_feedback_0.2', 'distortion_drive_db_18', 'phaser_mix_0.5', 'compressor_attack_ms_70', 'phaser_feedback_0.4', 'compressor_ratio_4', 'phaser_depth_0.2', '<sep>', 'phaser_feedback_0.6', 'chorus_depth_0.25', '<sep>', 'compressor_attack_ms_70', 'reverb_damping_1', '<sep>', 'phaser_depth_0.7', 'compressor_release_ms_300', 'chorus_mix_0.7', '<sep>', '<sep>', 'phaser_depth_0.4']
# ['<start>', 'phaser_centre_frequency_hz_1500', 'compressor_ratio_1.5', 'phaser_depth_0.2', 'compressor_attack_ms_10', '<sep>', 'phaser_depth_0.2', '<sep>', '<sep>', 'reverb_damping_0', 'phaser_depth_0.7', 'reverb_damping_0', '<sep>', '<end>', '<sep>', 'phaser_depth_0.2', 'compressor_attack_ms_100', 'compressor_attack_ms_10', 'reverb_width_0.5', 'compressor_ratio_1.5', '<sep>', 'compressor_ratio_1.5', 'compressor_release_ms_100', 'chorus_mix_0.5', 'reverb_wet_level_0.7', 'reverb_width_0.5', 'phaser_feedback_0.6', '<sep>', 'chorus_rate_hz_0.5', 'compressor_release_ms_500', 'phaser_depth_1', 'phaser_depth_0.4']
# ['<start>', 'phaser_mix_0.5', 'compressor_release_ms_500', 'compressor_attack_ms_70', '<sep>', 'compressor_attack_ms_70', 'reverb_damping_0.5', 'phaser_feedback_0.4', '<sep>', 'chorus_mix_0.7', 'compressor_attack_ms_70', '<sep>', '<sep>', 'compressor_ratio_2', 'compressor_attack_ms_100', '<sep>', 'phaser_depth_0.7', 'compressor_release_ms_500', 'compressor_attack_ms_100', '<sep>', 'chorus_rate_hz_0.5', 'phaser_mix_0.5', 'phaser_rate_hz_0.2', '<sep>', 'chorus_mix_0.7', '<sep>', 'reverb_room_size_1', 'compressor_attack_ms_70', 'phaser_feedback_0.4', 'compressor_ratio_1.5', 'compressor_attack_ms_10', '<sep>']
# ['<start>', 'compressor_attack_ms_10', 'phaser_centre_frequency_hz_800', 'compressor_attack_ms_70', 'compressor_threshold_db_-30', 'compressor_ratio_2', 'compressor_release_ms_500', 'chorus_depth_0.15', 'chorus_depth_0.25', '<sep>', '<sep>', '<sep>', '<sep>', '<sep>', 'compressor_attack_ms_10', '<end>', 'phaser_centre_frequency_hz_300', 'compressor_release_ms_500', 'compressor_attack_ms_100', 'phaser_feedback_0.4', 'phaser_depth_0.7', '<sep>', 'reverb_width_1', 'phaser_depth_0.2', '<sep>', 'compressor_threshold_db_-20', 'compressor_ratio_10', '<sep>', 'chorus_depth_0.25', '<sep>', '<sep>', 'phaser_depth_0.7']
# ['<start>', 'reverb_width_0.5', 'chorus_depth_0.05', 'compressor_attack_ms_10', 'reverb_width_0.5', 'compressor_ratio_4', 'chorus_depth_0.15', 'compressor_attack_ms_100', 'reverb_width_0.5', 'reverb_width_0.7', 'reverb_dry_level_1', 'reverb_width_0.5', '<sep>', 'compressor_attack_ms_100', 'reverb_width_0.7', 'chorus_feedback_0.4', 'phaser_rate_hz_3', 'compressor_threshold_db_-10', '<sep>', 'chorus_depth_0.15', 'phaser_centre_frequency_hz_1500', 'compressor_attack_ms_50', '<sep>', 'reverb_width_0.5', 'distortion_drive_db_18', 'compressor_release_ms_50', 'chorus_depth_0.05', 'compressor_release_ms_50', 'compressor_threshold_db_-30', 'reverb_width_1', 'chorus_centre_delay_ms_30', 'reverb_width_0.5']
# ['<start>', 'chorus_rate_hz_0.8', 'compressor_attack_ms_70', 'compressor_release_ms_50', '<sep>', '<sep>', 'chorus_mix_0.7', '<sep>', 'phaser_rate_hz_3', 'compressor_ratio_2', '<sep>', 'chorus_depth_0.15', 'chorus_feedback_0.2', '<sep>', 'compressor_threshold_db_-20', 'compressor_ratio_2', 'compressor_attack_ms_50', 'distortion_drive_db_18', 'phaser_centre_frequency_hz_300', '<sep>', 'chorus_depth_0.05', '<sep>', 'compressor_threshold_db_-20', '<sep>', 'compressor_attack_ms_10', 'compressor_attack_ms_50', '<sep>', 'compressor_attack_ms_10', 'compressor_ratio_2', 'compressor_threshold_db_-60', 'distortion_drive_db_24', '<sep>']
# ['<start>', 'phaser_feedback_0.6', 'reverb_room_size_0.5', 'compressor_ratio_1.5', 'compressor_attack_ms_100', 'phaser_mix_0.5', 'compressor_ratio_10', 'phaser_depth_0.4', 'phaser_mix_0.5', 'compressor_ratio_4', '<sep>', 'phaser_depth_0.2', 'compressor_threshold_db_-10', 'reverb_damping_0.5', 'compressor_threshold_db_-60', 'reverb_room_size_0.7', 'phaser_mix_0.5', 'phaser_depth_0.2', '<sep>', 'phaser_rate_hz_3', 'chorus_rate_hz_1', 'chorus_rate_hz_0.8', '<sep>', 'compressor_ratio_2', 'phaser_feedback_0.4', 'compressor_ratio_2', 'chorus_rate_hz_0.5', 'compressor_attack_ms_70', 'compressor_attack_ms_100', 'phaser_mix_0.5', 'compressor_threshold_db_-50', 'chorus_rate_hz_0.8']
# ['<start>', 'chorus_feedback_0.2', 'chorus_depth_0.15', 'phaser_depth_0.4', 'compressor_release_ms_300', 'phaser_rate_hz_3', 'chorus_feedback_0.2', 'chorus_depth_0.25', 'reverb_width_0.5', 'compressor_release_ms_150', 'distortion_drive_db_12', 'compressor_attack_ms_10', 'compressor_release_ms_500', 'distortion_drive_db_24', 'phaser_depth_0.4', 'chorus_feedback_0.2', 'reverb_width_0.7', '<sep>', 'reverb_room_size_1', 'distortion_drive_db_12', 'compressor_threshold_db_-10', '<sep>', 'chorus_rate_hz_0.8', 'distortion_drive_db_12', '<sep>', 'compressor_attack_ms_70', 'chorus_rate_hz_0.5', 'phaser_rate_hz_1', 'compressor_threshold_db_-50', 'chorus_rate_hz_0.8', '<sep>', 'phaser_depth_0.7']
# ['<start>', '<sep>', 'phaser_centre_frequency_hz_2000', 'phaser_rate_hz_0.2', '<sep>', 'compressor_attack_ms_70', '<sep>', 'phaser_centre_frequency_hz_300', 'phaser_mix_0.5', 'compressor_attack_ms_10', 'compressor_release_ms_500', 'phaser_centre_frequency_hz_300', 'distortion_drive_db_12', 'compressor_ratio_4', 'compressor_attack_ms_100', 'compressor_attack_ms_10', 'compressor_ratio_2', 'phaser_centre_frequency_hz_1500', 'phaser_centre_frequency_hz_2000', 'compressor_attack_ms_10', 'reverb_room_size_0.3', 'chorus_feedback_0.4', '<sep>', 'compressor_release_ms_300', 'phaser_centre_frequency_hz_300', '<sep>', 'compressor_threshold_db_-40', 'compressor_threshold_db_-40', '<sep>', 'reverb_damping_1', 'phaser_rate_hz_3', '<sep>']
# ['<start>', '<sep>', '<sep>', 'distortion_drive_db_18', '<sep>', 'chorus_centre_delay_ms_20', '<sep>', 'compressor_attack_ms_50', 'chorus_depth_0.05', '<sep>', 'chorus_centre_delay_ms_5', '<sep>', 'compressor_attack_ms_10', 'compressor_attack_ms_100', '<sep>', 'chorus_mix_0.7', '<sep>', '<sep>', 'phaser_centre_frequency_hz_1500', 'phaser_depth_0.2', 'chorus_centre_delay_ms_20', 'phaser_depth_0.2', '<sep>', 'reverb_width_0.5', 'chorus_mix_0.7', 'phaser_depth_0.7', '<sep>', 'compressor_ratio_2', 'reverb_room_size_0.5', 'chorus_centre_delay_ms_5', 'phaser_rate_hz_0.2', 'reverb_room_size_0.5']
# ['<start>', 'compressor_attack_ms_100', 'chorus_rate_hz_0.8', '<sep>', 'compressor_attack_ms_70', 'phaser_depth_0.4', '<sep>', 'reverb_wet_level_1', 'reverb_room_size_0.7', 'compressor_ratio_4', '<sep>', 'reverb_wet_level_0.5', '<sep>', 'compressor_attack_ms_50', 'compressor_attack_ms_70', 'compressor_attack_ms_70', 'compressor_attack_ms_10', 'reverb_wet_level_1', 'compressor_attack_ms_10', 'phaser_feedback_0.4', 'compressor_ratio_4', '<sep>', 'compressor_ratio_4', 'phaser_mix_0.5', '<sep>', 'compressor_attack_ms_70', 'phaser_mix_0.5', '<sep>', 'phaser_depth_0.4', 'compressor_attack_ms_100', 'phaser_feedback_0.4', 'compressor_attack_ms_100']
# ['<start>', '<sep>', 'chorus_depth_0.05', 'compressor_release_ms_150', 'chorus_mix_0.5', '<sep>', 'chorus_mix_1', 'chorus_mix_0.7', 'reverb_damping_0.5', 'phaser_centre_frequency_hz_800', 'phaser_feedback_0.4', '<sep>', 'compressor_release_ms_500', 'chorus_depth_0.05', 'compressor_release_ms_150', 'compressor_ratio_4', 'compressor_attack_ms_50', '<sep>', 'compressor_attack_ms_10', '<sep>', '<sep>', 'reverb_wet_level_0.7', '<end>', '<sep>', 'reverb_wet_level_0.5', 'chorus_mix_0.7', 'compressor_release_ms_150', '<sep>', '<sep>', '<sep>', 'compressor_attack_ms_50', '<sep>']
# ['<start>', 'compressor_ratio_1.5', 'chorus_mix_0.5', 'phaser_centre_frequency_hz_300', 'phaser_centre_frequency_hz_300', '<end>', 'reverb_wet_level_0.7', 'reverb_wet_level_1', '<sep>', 'compressor_attack_ms_100', 'chorus_centre_delay_ms_15', 'phaser_centre_frequency_hz_2000', 'chorus_depth_0.05', '<sep>', 'reverb_wet_level_0.7', '<sep>', 'reverb_wet_level_1', 'compressor_ratio_2', 'chorus_centre_delay_ms_5', 'reverb_width_0.5', 'reverb_room_size_0.1', '<end>', 'phaser_depth_0.4', 'reverb_damping_0', 'chorus_mix_0.7', 'chorus_rate_hz_0.8', 'reverb_wet_level_0.7', 'reverb_damping_0.5', 'reverb_dry_level_0.7', 'compressor_ratio_1.5', 'reverb_wet_level_0.5', '<end>']
